# %%
from pandas_datareader import data as  web
import pandas as pd
import matplotlib.pyplot as plt

bovespa = web.DataReader('^IXIC',data_source = 'yahoo', start = '01-01-2020', end = '01-01-2021')
display(bovespa)

bovespa["Adj Close"].plot(figsize=(15, 10,))
plt.show()
# Out:
#                     High           Low          Open         Close  \
# Date
# 2020-01-02   9093.429688   9010.889648   9039.459961   9092.190430
# 2020-01-03   9065.759766   8976.429688   8976.429688   9020.769531
# 2020-01-06   9072.410156   8943.500000   8943.500000   9071.469727
# 2020-01-07   9091.929688   9042.549805   9076.639648   9068.580078
# 2020-01-08   9168.889648   9059.379883   9068.030273   9129.240234
# ...                  ...           ...           ...           ...
# 2020-12-24  12833.549805  12767.639648  12791.540039  12804.730469
# 2020-12-28  12930.889648  12827.450195  12914.639648  12899.419922
# 2020-12-29  12973.330078  12821.959961  12965.389648  12850.219727
# 2020-12-30  12924.929688  12857.759766  12906.509766  12870.000000
# 2020-12-31  12902.070312  12821.230469  12877.089844  12888.280273
#
#                 Volume     Adj Close
# Date
# 2020-01-02  2848370000   9092.190430
# 2020-01-03  2567400000   9020.769531
# ...
